# %%
import pandas as pd
import re
pd.options.display.max_colwidth = 200
df = pd.read_pickle("../data/preprocessed/diagnoses.pkl")
diag_unique_patients = df[["patient_id"]].drop_duplicates()
print(f"N. unique patients in diagnoses: {len(diag_unique_patients)}")
print(f"N. rows diag: {len(df)}")
# Out:
# N. unique patients in diagnoses: 15663
# N. rows diag: 138718

# %%
df_age_sex = pd.read_excel("../data/raw/hackath 112022 - Age SEX CKD.xlsx")
df_bmi = pd.read_excel("../data/raw/hackath 112022 - BMI weight height CKD 1.xlsx")

# %%
# validate NAs and how the dataset match on top of each other
print("### NAs age sex")
print(df_age_sex.isna().sum())
print("### NAs bmi")
print(df_bmi.isna().sum())

age_unique_patients = df_age_sex[["Patient"]].drop_duplicates()
bmi_unique_patients = df_bmi[["Patient"]].drop_duplicates()
print("### Datasets joinability")
print(f'{len(diag_unique_patients.merge(age_unique_patients, how = "inner", left_on = ["patient_id"], right_on = "Patient"))/len(diag_unique_patients)*100} % have age sex info')
print(f'{len(diag_unique_patients.merge(bmi_unique_patients, how = "inner", left_on = ["patient_id"], right_on = "Patient"))/len(diag_unique_patients)*100} % have bmi info')
# Out:
# ### NAs age sex
# Patient    0
# Sex        0
# Age        0
# dtype: int64
# ### NAs bmi
# Patient             0
# date                0
# BMI                 0
# Weight (kg)         0
# Height (cm)    141417
# dtype: int64
# ### Datasets joinability
# 99.32324586605375 % have age sex info
# 91.5788801634425 % have bmi info

# %%
df_age_sex.rename(columns = {"Patient": "patient_id", "Sex": "sex", "Age": "age_2022"}, inplace = True)
df = df.merge(df_age_sex, on = "patient_id", how = "left")
df["age_date"] = pd.to_datetime(pd.Timestamp.now())
df["age"] = df["age_2022"] -  pd.to_timedelta(df["age_date"] - df["date"]).dt.days/365
df
# Out:
#         patient_id       date main_code  \
# 0           209536 2015-01-29     E06.3
# 1           209536 2015-08-06     Z01.4
# 2           209536 2022-01-10     E06.3
# 3           209536 2022-04-04     D25.1
# 4           209536 2022-06-01     Z01.4
# ...            ...        ...       ...
# 138713     1217771 2015-11-11     K50.8
# 138714     1217771 2022-07-29     K50.8
# 138715     1217771 2022-07-29     K50.8
# 138716     1217771 2022-03-25     K50.8
# 138717     1217771 2022-01-14     K50.8
#
#                                                                                 main_description  \
# 0                                                                       Autoimunitní tyroiditida
# 1                                                   Gynekologické vyšetření (všeobecné)(rutinní)
# 2                                                                       Autoimunitní tyroiditida
# 3                                                                   Intramurální leiomyom dělohy
# 4                                                   Gynekologické vyšetření (všeobecné)(rutinní)
# ...                                                                                          ...
# 138713  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 138714  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 138715  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 138716       Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 138717  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
#
#        other_code                 other_description  is_ckd  is_dia  \
# 0           E78.0        Čistá hypercholesterolemie       0       0
# 1           N83.1             Cysta žlutého tělíska       0       0
# 2           E78.0        Čistá hypercholesterolemie       0       0
# 3             NaN                               NaN       0       0
# 4           D25.1      Intramurální leiomyom dělohy       0       0
# ...           ...                               ...     ...     ...
# 138713        K20         Zánět jícnu - ezofagitida       0       0
# 138714        I10  Esenciální (primární) hypertenze       0       0
# 138715        NaN              Hypercholesterolemie       0       0
# 138716        NaN                               NaN       0       0
# 138717        NaN                               NaN       0       0
#
#        ckd_stadium   min_date  ... is_dia_patient  date_range  min_ckd_date  \
# 0              NaN 2015-01-29  ...              0   2680 days           NaT
# 1              NaN 2015-01-29  ...              0   2680 days           NaT
# 2              NaN 2015-01-29  ...              0   2680 days           NaT
# 3              NaN 2015-01-29  ...              0   2680 days           NaT
# 4              NaN 2015-01-29  ...              0   2680 days           NaT
# ...            ...        ...  ...            ...         ...           ...
# 138713         NaN 2015-11-11  ...              0   2452 days           NaT
# 138714         NaN 2015-11-11  ...              0   2452 days           NaT
# 138715         NaN 2015-11-11  ...              0   2452 days           NaT
# 138716         NaN 2015-11-11  ...              0   2452 days           NaT
# 138717         NaN 2015-11-11  ...              0   2452 days           NaT
#
#         min_dia_date  is_ckd_cum is_dia_cum sex age_2022  \
# 0                NaT           0          0   F     38.9
# 1                NaT           0          0   F     38.9
# 2                NaT           0          0   F     38.9
# 3                NaT           0          0   F     38.9
# 4                NaT           0          0   F     38.9
# ...              ...         ...        ...  ..      ...
# 138713           NaT           0          0   M     42.9
# 138714           NaT           0          0   M     42.9
# 138715           NaT           0          0   M     42.9
# 138716           NaT           0          0   M     42.9
# 138717           NaT           0          0   M     42.9
#
#                          age_date        age
# 0      2022-11-26 10:42:34.826636  31.069863
# 1      2022-11-26 10:42:34.826636  31.587671
# 2      2022-11-26 10:42:34.826636  38.023288
# 3      2022-11-26 10:42:34.826636  38.253425
# 4      2022-11-26 10:42:34.826636  38.412329
# ...                           ...        ...
# 138713 2022-11-26 10:42:34.826636  35.853425
# 138714 2022-11-26 10:42:34.826636  42.571233
# 138715 2022-11-26 10:42:34.826636  42.571233
# 138716 2022-11-26 10:42:34.826636  42.226027
# 138717 2022-11-26 10:42:34.826636  42.034247
#
# [138718 rows x 24 columns]

# %%
df_bmi["bmi_fom"] = df_bmi['date'].dt.normalize() - pd.offsets.MonthBegin(1)
df_bmi.rename(columns = {"BMI": "bmi", "Patient": "patient_id"}, inplace = True)
df_bmi
# Out:
#         patient_id       date   bmi  Weight (kg)  Height (cm)    bmi_fom
# 0           324729 2015-04-08  29.4         93.0          NaN 2015-04-01
# 1           324729 2015-08-28  29.4         93.0          NaN 2015-08-01
# 2           324729 2016-02-03  26.2         83.0          NaN 2016-02-01
# 3           324729 2016-03-30  30.1         90.0        173.0 2016-03-01
# 4           324729 2016-05-02  30.1         90.0        173.0 2016-05-01
# ...            ...        ...   ...          ...          ...        ...
# 153246      335472 2021-02-22  30.9         98.0          NaN 2021-02-01
# 153247      335472 2021-09-13  30.9         98.0          NaN 2021-09-01
# 153248      335472 2022-03-21  30.6         97.0          NaN 2022-03-01
# 153249      335472 2022-05-13  29.5         93.4          NaN 2022-05-01
# 153250      335472 2022-09-29  29.4         93.0          NaN 2022-09-01
#
# [153251 rows x 6 columns]

# %%
date_range = pd.DataFrame({"fom": pd.date_range(start=df["date"].min(), end=df["date"].max(), freq="MS",inclusive="both")})
diag_unique_patients["key"] = 0
date_range['key'] = 0
skeleton = diag_unique_patients.merge(date_range, on = "key", how = "inner")
skeleton_bmi = skeleton.merge(df_bmi, left_on = ["patient_id", "fom"], right_on = ["patient_id", "bmi_fom"], how = "left")
skeleton_bmi = skeleton_bmi.drop_duplicates(subset = ["patient_id", "fom"])
print(skeleton_bmi.isna().sum())
skeleton_bmi["bmi"] = skeleton_bmi.groupby('patient_id')["bmi"].apply(lambda group: group.interpolate(method='linear', limit_area = "inside"))
skeleton_bmi["bmi"] = skeleton_bmi.groupby('patient_id')['bmi'].apply(lambda x: x.bfill().ffill())
print(skeleton_bmi.isna().sum())
#z.merge(df, on = "key")
# TODO: Add fom to df
# bmi to z + interpolation
# Out:
# patient_id           0
# key                  0
# fom                  0
# date           1362215
# bmi            1362215
# Weight (kg)    1362215
# Height (cm)    1503588
# bmi_fom        1362215
# dtype: int64
# C:\Users\pavel\AppData\Local\Temp\ipykernel_3280\3218017658.py:7: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   skeleton_bmi["bmi"] = skeleton_bmi.groupby('patient_id')["bmi"].apply(lambda group: group.interpolate(method='linear', limit_area = "inside"))
# C:\Users\pavel\AppData\Local\Temp\ipykernel_3280\3218017658.py:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   skeleton_bmi["bmi"] = skeleton_bmi.groupby('patient_id')['bmi'].apply(lambda x: x.bfill().ffill())
# patient_id           0
# key                  0
# fom                  0
# date           1362215
# bmi             126624
# Weight (kg)    1362215
# Height (cm)    1503588
# bmi_fom        1362215
# dtype: int64

# %%
skeleton_bmi.drop(columns = ["date"], inplace = True)

# %%
skeleton_bmi.drop_duplicates(subset = ["patient_id", "fom"]).shape
# Out:
# (1503648, 7)

# %%
df["date_fom"] = df['date'].dt.normalize() - pd.offsets.MonthBegin(1)
df = df.merge(skeleton_bmi, left_on = ["patient_id", "date_fom"], right_on = ["patient_id", "bmi_fom"])

# %%
df.drop(columns = ["key", "Weight (kg)", "Height (cm)", "age_date", "bmi_fom"], inplace = True, errors="ignore")
df
# Out:
#        patient_id       date main_code  \
# 0          209536 2015-01-29     E06.3
# 1          209536 2022-01-10     E06.3
# 2            8451 2015-01-08     E10.9
# 3            8451 2015-01-08     E10.9
# 4            8451 2015-01-08     E10.9
# ...           ...        ...       ...
# 95612     1245853 2022-07-14     K51.0
# 95613     1217771 2015-11-11     K50.8
# 95614     1217771 2022-07-29     K50.8
# 95615     1217771 2022-07-29     K50.8
# 95616     1217771 2022-03-25     K50.8
#
#                                                                                main_description  \
# 0                                                                      Autoimunitní tyroiditida
# 1                                                                      Autoimunitní tyroiditida
# 2                          Diabetes mellitus 1. typu, léč. intenzifikovaným inzulínovým režimem
# 3                          Diabetes mellitus 1. typu, léč. intenzifikovaným inzulínovým režimem
# 4                          Diabetes mellitus 1. typu, léč. intenzifikovaným inzulínovým režimem
# ...                                                                                         ...
# 95612                                                            Ulcerózní pankolitida (5/2015)
# 95613  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 95614  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 95615  Jiná Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
# 95616       Crohnova nemoc - postižení ileocéka a sigmatu, st.p. chir. řešení perianál. píštěle
#
#       other_code                 other_description  is_ckd  is_dia  \
# 0          E78.0        Čistá hypercholesterolemie       0       0
# 1          E78.0        Čistá hypercholesterolemie       0       0
# 2            NaN           Autoimunní thyreoiditis       0       1
# 3            NaN                Perniciózní anemie       0       1
# 4            NaN    Surditas vlevo, tinnitus vlevo       0       1
# ...          ...                               ...     ...     ...
# 95612        NaN        Stav po borelióze (6/2022)       0       0
# 95613        K20         Zánět jícnu - ezofagitida       0       0
# 95614        I10  Esenciální (primární) hypertenze       0       0
# 95615        NaN              Hypercholesterolemie       0       0
# 95616        NaN                               NaN       0       0
#
#       ckd_stadium   min_date  ... min_ckd_date  min_dia_date  is_ckd_cum  \
# 0             NaN 2015-01-29  ...          NaT           NaT           0
# 1             NaN 2015-01-29  ...          NaT           NaT           0
# 2             NaN 2015-01-08  ...          NaT    2015-01-08           0
# 3             NaN 2015-01-08  ...          NaT    2015-01-08           0
# 4             NaN 2015-01-08  ...          NaT    2015-01-08           0
# ...           ...        ...  ...          ...           ...         ...
# 95612         NaN 2015-06-01  ...          NaT           NaT           0
# 95613         NaN 2015-11-11  ...          NaT           NaT           0
# 95614         NaN 2015-11-11  ...          NaT           NaT           0
# 95615         NaN 2015-11-11  ...          NaT           NaT           0
# 95616         NaN 2015-11-11  ...          NaT           NaT           0
#
#        is_dia_cum  sex age_2022        age   date_fom        fom   bmi
# 0               0    F     38.9  31.069863 2015-01-01 2015-01-01  45.1
# 1               0    F     38.9  38.023288 2022-01-01 2022-01-01  31.0
# 2               0    M     62.8  54.912329 2015-01-01 2015-01-01  26.9
# 3               0    M     62.8  54.912329 2015-01-01 2015-01-01  26.9
# 4               0    M     62.8  54.912329 2015-01-01 2015-01-01  26.9
# ...           ...  ...      ...        ...        ...        ...   ...
# 95612           0    M     30.9  30.530137 2022-07-01 2022-07-01  21.2
# 95613           0    M     42.9  35.853425 2015-11-01 2015-11-01  25.3
# 95614           0    M     42.9  42.571233 2022-07-01 2022-07-01  26.9
# 95615           0    M     42.9  42.571233 2022-07-01 2022-07-01  26.9
# 95616           0    M     42.9  42.226027 2022-03-01 2022-03-01  26.6
#
# [95617 rows x 26 columns]

# %%
pd.options.display.max_rows = 50
skeleton_bmi.loc[skeleton_bmi["patient_id"] == 1217771, :]
# Out:
#          patient_id  key        fom       date   bmi  Weight (kg)  \
# 1515308     1217771    0 2015-01-01        NaT   NaN          NaN
# 1515309     1217771    0 2015-02-01        NaT   NaN          NaN
# 1515310     1217771    0 2015-03-01        NaT   NaN          NaN
# 1515311     1217771    0 2015-04-01        NaT   NaN          NaN
# 1515312     1217771    0 2015-05-01        NaT   NaN          NaN
# ...             ...  ...        ...        ...   ...          ...
# 1515407     1217771    0 2022-08-01 2022-08-31  27.8         91.0
# 1515408     1217771    0 2022-09-01        NaT   NaN          NaN
# 1515409     1217771    0 2022-10-01        NaT   NaN          NaN
# 1515410     1217771    0 2022-11-01        NaT   NaN          NaN
# 1515411     1217771    0 2022-12-01        NaT   NaN          NaN
#
#          Height (cm)    bmi_fom
# 1515308          NaN        NaT
# 1515309          NaN        NaT
# 1515310          NaN        NaT
# 1515311          NaN        NaT
# 1515312          NaN        NaT
# ...              ...        ...
# 1515407          NaN 2022-08-01
# 1515408          NaN        NaT
# 1515409          NaN        NaT
# 1515410          NaN        NaT
# 1515411          NaN        NaT
#
# [104 rows x 8 columns]
